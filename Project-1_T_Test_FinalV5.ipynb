# %% [markdown]
# This is a sample

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
import scipy.stats as stats
import numpy as np

# %%
# Create a file path
crimes=pd.read_csv("Resources\Crimes_2015toPresent.csv")
crimes.head()
# Out:
#    District       Primary Type  Arrest                    Date  IUCR  \
# 0       1.0              ARSON    True  10/26/2015 07:06:00 PM  1090
# 1       6.0  WEAPONS VIOLATION    True  10/09/2018 11:22:00 PM  143A
# 2       6.0  WEAPONS VIOLATION    True  10/09/2018 12:27:00 AM  143A
# 3       6.0  WEAPONS VIOLATION    True  10/08/2018 10:00:00 PM  143A
# 4       6.0  WEAPONS VIOLATION    True  10/08/2018 02:38:00 PM  143A
#
#                 Description    Location Description FBI Code  Year   Latitude  \
# 0             ATTEMPT ARSON       CONSTRUCTION SITE       09  2015  41.885874
# 1  UNLAWFUL POSS OF HANDGUN                  STREET       15  2018  41.750717
# 2  UNLAWFUL POSS OF HANDGUN                  STREET       15  2018  41.752899
# 3  UNLAWFUL POSS OF HANDGUN  VEHICLE NON-COMMERCIAL       15  2018  41.758364
# 4  UNLAWFUL POSS OF HANDGUN                  STREET       15  2018  41.744909
#
#    Longitude
# 0 -87.625284
# 1 -87.638868
# 2 -87.617435
# 3 -87.617594
# ...

# %%
#count the number of arrests per year
total_arrests_per_year = crimes.groupby('Year').size()
total_arrests_per_year
# Out:
# Year
# 2015     82780
# 2016    127802
# 2017    126245
# 2018    127465
# 2019     58977
# 2020      7144
# 2021      1090
# 2022        83
# 2023      1167
# dtype: int64

# %%
#plot the number of arrests per year
total_arrests_per_year.plot(kind='bar', color= 'r', alpha=0.5, align="edge")
plt.xticks(rotation="vertical")
plt.xlabel("Year")
plt.ylabel("Total Arrests Made")
plt.title("Total Arrests Made per Year")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#count the number of arrests per District
total_arrests_per_year = crimes.groupby('District').size()
total_arrests_per_year
# Out:
# District
# 1.0     10254
# 2.0      7247
# 3.0      9806
# 4.0     13049
# 5.0     11768
# 6.0     15806
# 7.0     15426
# 8.0     11684
# 9.0     10096
# 10.0    14743
# 11.0    42273
# 12.0    54080
# 14.0    39289
# 15.0    41019
# 16.0    16500
# 17.0     7120
# 18.0    43753
# 19.0    48723
# 20.0    18515
# 22.0    20444
# 24.0    23799
# 25.0    57332
# 31.0       27
# dtype: int64

# %%
#Create a DF showing a normal distribution based on arrest counts in each district
data = pd.Series(total_arrests_per_year)
z_scores = (data - data.mean()) / data.std()
percentile_ranks = norm.cdf(z_scores)
df_arranged = pd.DataFrame({'District': data.index, 'Arranged': percentile_ranks})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 4
#       2 data = pd.Series(total_arrests_per_year)
#       3 z_scores = (data - data.mean()) / data.std()
# ----> 4 percentile_ranks = norm.cdf(z_scores)
#       5 df_arranged = pd.DataFrame({'District': data.index, 'Arranged': percentile_ranks})
#
# NameError: name 'norm' is not defined

# %%
#count the number of arrests per year
total_arrests_per_year = crimes[crimes['Arrest'] == True].groupby('Year').size()
total_arrests_per_year
# Out:
# Year
# 2015    39908
# 2016    51806
# 2017    51592
# 2018    52314
# 2019    25715
# 2020     2194
# 2021      322
# 2022       33
# 2023      325
# dtype: int64

# %%
#create a data frame for only 2015
year2015df = crimes[crimes["Year"] == 2015].reset_index()
year2015df.head()
# Out:
#    index  District Primary Type  Arrest                    Date  IUCR  \
# 0      0       1.0        ARSON    True  10/26/2015 07:06:00 PM  1090
# 1    416       7.0      ASSAULT    True  09/16/2015 10:33:00 PM  0560
# 2    417       7.0      ASSAULT    True  09/16/2015 02:35:00 PM  0520
# 3    418       7.0      ASSAULT    True  09/13/2015 05:30:00 PM  0560
# 4    419       7.0      ASSAULT    True  09/13/2015 10:35:00 AM  0560
#
#                       Description Location Description FBI Code  Year  \
# 0                   ATTEMPT ARSON    CONSTRUCTION SITE       09  2015
# 1                          SIMPLE            APARTMENT      08A  2015
# 2  AGGRAVATED:KNIFE/CUTTING INSTR            RESIDENCE      04A  2015
# 3                          SIMPLE            APARTMENT      08A  2015
# 4                          SIMPLE   GROCERY FOOD STORE      08A  2015
#
#     Latitude  Longitude
# 0  41.885874 -87.625284
# 1  41.777310 -87.640803
# 2  41.773729 -87.648272
# ...

# %%
#create a data frame for only 2016
year2016df = crimes[crimes["Year"] == 2016]
year2016df.head()
# Out:
#      District Primary Type  Arrest                    Date  IUCR  \
# 415       7.0        ARSON    True  06/06/2016 11:20:00 PM  1025
# 453       7.0        ARSON    True  10/23/2016 09:09:00 PM  1025
# 454       7.0        ARSON    True  05/31/2016 12:22:00 AM  1090
# 456       7.0        ARSON    True  08/02/2016 09:26:00 PM  1090
# 478       7.0        ARSON    True  04/19/2016 12:30:00 PM  1020
#
#        Description           Location Description FBI Code  Year   Latitude  \
# 415     AGGRAVATED                          ALLEY       09  2016  41.768546
# 453     AGGRAVATED                      APARTMENT       09  2016  41.771907
# 454  ATTEMPT ARSON  RESIDENTIAL YARD (FRONT/BACK)       09  2016  41.762245
# 456  ATTEMPT ARSON                      RESIDENCE       09  2016  41.772257
# 478        BY FIRE                      RESIDENCE       09  2016  41.791476
#
#      Longitude
# 415 -87.664207
# 453 -87.644582
# 454 -87.659471
# 456 -87.659554
# 478 -87.675447

# %%
#create a data frame for only 2017
year2017df = crimes[crimes["Year"] == 2017]
year2017df.head()
# Out:
#      District        Primary Type  Arrest                    Date  IUCR  \
# 18       17.0  DECEPTIVE PRACTICE    True  11/29/2017 04:20:00 AM  1210
# 101      17.0  DECEPTIVE PRACTICE    True  10/21/2017 02:06:00 AM  1210
# 135      17.0  DECEPTIVE PRACTICE    True  12/19/2017 03:06:00 PM  1110
# 253      17.0  DECEPTIVE PRACTICE    True  12/10/2017 01:00:00 AM  1121
# 351      17.0  DECEPTIVE PRACTICE    True  08/11/2017 01:05:00 AM  1210
#
#                  Description Location Description FBI Code  Year   Latitude  \
# 18   THEFT OF LABOR/SERVICES               STREET       11  2017  41.953866
# 101  THEFT OF LABOR/SERVICES              TAXICAB       11  2017  41.949924
# 135              BOGUS CHECK    CURRENCY EXCHANGE       11  2017  41.953925
# 253  COUNTERFEITING DOCUMENT        BAR OR TAVERN       10  2017  41.953958
# 351  THEFT OF LABOR/SERVICES              TAXICAB       11  2017  41.944329
#
#      Longitude
# 18  -87.712238
# 101 -87.736262
# 135 -87.707362
# ...

# %%
#create a data frame for only 2018
year2018df = crimes[crimes["Year"] == 2018]
year2018df.head()
# Out:
#    District       Primary Type  Arrest                    Date  IUCR  \
# 1       6.0  WEAPONS VIOLATION    True  10/09/2018 11:22:00 PM  143A
# 2       6.0  WEAPONS VIOLATION    True  10/09/2018 12:27:00 AM  143A
# 3       6.0  WEAPONS VIOLATION    True  10/08/2018 10:00:00 PM  143A
# 4       6.0  WEAPONS VIOLATION    True  10/08/2018 02:38:00 PM  143A
# 5       6.0  WEAPONS VIOLATION    True  10/08/2018 12:13:00 PM  143A
#
#                 Description    Location Description FBI Code  Year   Latitude  \
# 1  UNLAWFUL POSS OF HANDGUN                  STREET       15  2018  41.750717
# 2  UNLAWFUL POSS OF HANDGUN                  STREET       15  2018  41.752899
# 3  UNLAWFUL POSS OF HANDGUN  VEHICLE NON-COMMERCIAL       15  2018  41.758364
# 4  UNLAWFUL POSS OF HANDGUN                  STREET       15  2018  41.744909
# 5  UNLAWFUL POSS OF HANDGUN                  STREET       15  2018  41.756655
#
#    Longitude
# 1 -87.638868
# 2 -87.617435
# 3 -87.617594
# 4 -87.603789
# ...

# %%
#create a data frame for only 2019
year2019df = crimes[crimes["Year"] == 2019]
year2019df.head()
# Out:
#      District       Primary Type  Arrest                    Date  IUCR  \
# 343       6.0  WEAPONS VIOLATION    True  06/01/2019 12:46:00 PM  143A
# 344       6.0  WEAPONS VIOLATION    True  06/02/2019 07:08:00 PM  143A
# 345       6.0  WEAPONS VIOLATION    True  05/31/2019 10:03:00 PM  143A
# 346       6.0  WEAPONS VIOLATION    True  05/27/2019 07:58:00 PM  143A
# 347       6.0  WEAPONS VIOLATION    True  05/27/2019 04:02:00 PM  143A
#
#                   Description Location Description FBI Code  Year   Latitude  \
# 343  UNLAWFUL POSS OF HANDGUN               STREET       15  2019  41.750462
# 344  UNLAWFUL POSS OF HANDGUN             SIDEWALK       15  2019  41.747600
# 345  UNLAWFUL POSS OF HANDGUN               STREET       15  2019  41.755359
# 346  UNLAWFUL POSS OF HANDGUN               STREET       15  2019  41.750879
# 347  UNLAWFUL POSS OF HANDGUN               STREET       15  2019  41.757934
#
#      Longitude
# 343 -87.610059
# 344 -87.607039
# 345 -87.653863
# ...

# %%
#create a data frame for only 2020
year2020df = crimes[crimes["Year"] == 2020]
year2020df.head()
# Out:
#      District       Primary Type  Arrest                    Date  IUCR  \
# 332       6.0  WEAPONS VIOLATION    True  12/13/2020 04:53:00 PM  143A
# 333       6.0  WEAPONS VIOLATION    True  08/11/2020 09:19:00 PM  143A
# 334       6.0  WEAPONS VIOLATION    True  08/11/2020 08:24:00 PM  143A
# 335       6.0  WEAPONS VIOLATION    True  03/24/2020 03:11:00 AM  143A
# 336       6.0  WEAPONS VIOLATION    True  12/12/2020 03:25:00 PM  141C
#
#                                Description    Location Description FBI Code  \
# 332          UNLAWFUL POSSESSION - HANDGUN                  STREET       15
# 333          UNLAWFUL POSSESSION - HANDGUN  VEHICLE NON-COMMERCIAL       15
# 334          UNLAWFUL POSSESSION - HANDGUN                  STREET       15
# 335          UNLAWFUL POSSESSION - HANDGUN                  STREET       15
# 336  UNLAWFUL USE - OTHER DANGEROUS WEAPON                  STREET       15
#
#      Year   Latitude  Longitude
# 332  2020  41.746288 -87.643914
# ...

# %%
#Arrests made per crime in only (Primary Type)
crime_2015 = year2015df[year2015df['Arrest'] == True].groupby('Primary Type').size()
crime_2015 = pd.DataFrame(crime_2015).reset_index()
crime_2015.columns = ["Primary Type", "Primcount"]
crime_2015
# Out:
#                          Primary Type  Primcount
# 0                               ARSON         33
# 1                             ASSAULT       2399
# 2                             BATTERY       6942
# 3                            BURGLARY        481
# 4   CONCEALED CARRY LICENSE VIOLATION         20
# 5                 CRIM SEXUAL ASSAULT         87
# 6                     CRIMINAL DAMAGE       1139
# 7             CRIMINAL SEXUAL ASSAULT          2
# 8                   CRIMINAL TRESPASS       2532
# 9                  DECEPTIVE PRACTICE        620
# 10                           GAMBLING        210
# 11                           HOMICIDE          6
# 12                  HUMAN TRAFFICKING          1
# 13   INTERFERENCE WITH PUBLIC OFFICER        736
# 14                       INTIMIDATION         10
# 15                         KIDNAPPING         10
# 16               LIQUOR LAW VIOLATION        174
# 17                MOTOR VEHICLE THEFT        595
# ...

# %%
#Re-arrange the "Primcount" column to be normally distributed
# Calculate mean and standard deviation
mean = crime_2015["Primcount"].mean()
std_dev = crime_2015["Primcount"].std()

# Generate a normal distribution with the same length as the DataFrame
normal_dist = np.random.normal(mean, std_dev, size=len(crime_2015))

# Sort the DataFrame by the "Primcount" column in descending order
crime_2015 = crime_2015.sort_values(by="Primcount", ascending=False)

# Update the "Primcount" column with the normal distribution values
crime_2015["Primcount"] = normal_dist

# Print the resulting DataFrame
print(crime_2015)
# Out:
#                          Primary Type    Primcount
# 18                          NARCOTICS -1938.551879
# 2                             BATTERY   207.599893
# 31                              THEFT  2757.979162
# 24                      OTHER OFFENSE  4845.402583
# 8                   CRIMINAL TRESPASS  2410.059753
# 1                             ASSAULT  1426.185565
# 32                  WEAPONS VIOLATION   -80.366619
# 27             PUBLIC PEACE VIOLATION   199.200469
# 6                     CRIMINAL DAMAGE -2266.659343
# 13   INTERFERENCE WITH PUBLIC OFFICER  1760.940712
# 25                       PROSTITUTION -2258.261700
# 9                  DECEPTIVE PRACTICE -1340.832648
# 17                MOTOR VEHICLE THEFT  3925.453709
# 28                            ROBBERY  4938.131766
# 3                            BURGLARY  4209.058401
# 22         OFFENSE INVOLVING CHILDREN   763.296140
# 10                           GAMBLING -2520.984586
# ...

# %%
#Arrests made per crime in only 2016 (Primary Type)
crime_2016 = year2016df[year2016df['Arrest'] == True].groupby('Primary Type').size()
crime_2016 = pd.DataFrame(crime_2016).reset_index()
crime_2016.columns = ["Primary Type", "Primcount"]
crime_2016.head()
# Out:
#                         Primary Type  Primcount
# 0                              ARSON         52
# 1                            ASSAULT       3379
# 2                            BATTERY      10144
# 3                           BURGLARY        666
# 4  CONCEALED CARRY LICENSE VIOLATION         33

# %%
#Arrests made per crime in only 2017 (Primary Type)
crime_2017 = year2017df[year2017df['Arrest'] == True].groupby('Primary Type').size()
crime_2017 = pd.DataFrame(crime_2017).reset_index()
crime_2017.columns = ["Primary Type", "Primcount"]
crime_2017.head()
# Out:
#                         Primary Type  Primcount
# 0                              ARSON         36
# 1                            ASSAULT       3365
# 2                            BATTERY       9878
# 3                           BURGLARY        608
# 4  CONCEALED CARRY LICENSE VIOLATION         66

# %%
#Arrests made per crime in only 2018 (Primary Type)
crime_2018 = year2018df[year2018df['Arrest'] == True].groupby('Primary Type').size()
crime_2018 = pd.DataFrame(crime_2018).reset_index()
crime_2018.columns = ["Primary Type", "Primcount"]
crime_2018.head()
# Out:
#                         Primary Type  Primcount
# 0                              ARSON         37
# 1                            ASSAULT       3284
# 2                            BATTERY      10065
# 3                           BURGLARY        558
# 4  CONCEALED CARRY LICENSE VIOLATION        142

# %%
#Arrests made per crime in only 2019 (Primary Type)
crime_2019 = year2019df[year2019df['Arrest'] == True].groupby('Primary Type').size()
crime_2019 = pd.DataFrame(crime_2019).reset_index()
crime_2019.columns = ["Primary Type", "Primcount"]
crime_2019.head()
# Out:
#                         Primary Type  Primcount
# 0                              ARSON          7
# 1                            ASSAULT       1751
# 2                            BATTERY       4839
# 3                           BURGLARY        208
# 4  CONCEALED CARRY LICENSE VIOLATION         94

# %%
#Arrests made per crime in only 2020 (Primary Type)
crime_2020 = year2020df[year2020df['Arrest'] == True].groupby('Primary Type').size()
crime_2020 = pd.DataFrame(crime_2020).reset_index()
crime_2020.columns = ["Primary Type", "Primcount"]
crime_2020.head()
# Out:
#                         Primary Type  Primcount
# 0                            ASSAULT        184
# 1                            BATTERY        554
# 2                           BURGLARY         19
# 3  CONCEALED CARRY LICENSE VIOLATION          5
# 4                    CRIMINAL DAMAGE         65

# %%
#Average of 2015 offense being true
crime_2015.Primcount.mean()
# Out:
# 1048.5996316017163

# %%
#Average of 2016 offense being true
crime_2016.Primcount.mean()
# Out:
# 1569.878787878788

# %%
#Average of 2017 offense being true
crime_2017.Primcount.mean()
# Out:
# 1563.3939393939395

# %%
#Average of 2018 offense being true
crime_2018.Primcount.mean()
# Out:
# 1634.8125

# %%
#Average of 2019 offense being true
crime_2019.Primcount.mean()
# Out:
# 857.1666666666666

# %%
#Average of 2020 offense being true
crime_2020.Primcount.mean()
# Out:
# 109.7

# %%
# Note: Setting equal_var=False performs Welch's t-test which does 
# not assume equal population variance for 2015 AND 2016
stats.ttest_ind(crime_2015.Primcount, crime_2016.Primcount, equal_var=False)
# Out:
# Ttest_indResult(statistic=-0.8156210993701961, pvalue=0.418070063240637)

# %%
# Note: Setting equal_var=False performs Welch's t-test which does 
# not assume equal population variance for 2015 AND 2017
stats.ttest_ind(crime_2015.Primcount, crime_2017.Primcount, equal_var=False)
# Out:
# Ttest_indResult(statistic=-0.837791358698119, pvalue=0.40550080273510514)

# %%
# Note: Setting equal_var=False performs Welch's t-test which does 
# not assume equal population variance for 2015 AND 2018
stats.ttest_ind(crime_2015.Primcount, crime_2018.Primcount, equal_var=False)
# Out:
# Ttest_indResult(statistic=-0.8989794866649016, pvalue=0.37255905486008756)

# %%
# Note: Setting equal_var=False performs Welch's t-test which does 
# not assume equal population variance for 2015 AND 2019
stats.ttest_ind(crime_2015.Primcount, crime_2019.Primcount, equal_var=False)
# Out:
# Ttest_indResult(statistic=0.40847462786816197, pvalue=0.6844111993674864)

# %%
# Note: Setting equal_var=False performs Welch's t-test which does 
# not assume equal population variance for 2015 AND 2020
stats.ttest_ind(crime_2015.Primcount, crime_2020.Primcount, equal_var=False)
# Out:
# Ttest_indResult(statistic=2.5257629561752086, pvalue=0.016589045427415124)

# %%
#Scatter Plot comparing 2015 data to 2016
# Scatter Plot of Data
plt.subplot(2, 1, 1)
plt.scatter(range(len(crime_2015.Primcount)), crime_2015.Primcount, label="crime_2015")
plt.scatter(range(len(crime_2016.Primcount)), crime_2016.Primcount, label="crime_2016")
plt.legend()

# Histogram Plot of Data
plt.subplot(2, 1, 2)
plt.hist(crime_2015.Primcount, 10, density=True, alpha=0.7, label="crime_2015")
plt.hist(crime_2016.Primcount, 10, density=True, alpha=0.7, label="crime_2016")
plt.axvline(crime_2015.Primcount.mean(), color='k', linestyle='dashed', linewidth=1)
plt.axvline(crime_2016.Primcount.mean(), color='k', linestyle='dashed', linewidth=1)
plt.legend()

# %%
#Scatter Plot comparing 2015 data to 2018
# Scatter Plot of Data
plt.subplot(2, 1, 1)
plt.scatter(range(len(crime_2015.Primcount)), crime_2015.Primcount, label="crime_2015")
plt.scatter(range(len(crime_2018.Primcount)), crime_2018.Primcount, label="crime_2018")
plt.legend()

# Histogram Plot of Data
plt.subplot(2, 1, 2)
plt.hist(crime_2015.Primcount, 10, density=True, alpha=0.7, label="crime_2015")
plt.hist(crime_2018.Primcount, 10, density=True, alpha=0.7, label="crime_2018")
plt.axvline(crime_2015.Primcount.mean(), color='k', linestyle='dashed', linewidth=1)
plt.axvline(crime_2018.Primcount.mean(), color='k', linestyle='dashed', linewidth=1)
plt.legend()

# %%
#Scatter Plot comparing 2015 data to 2020
# Scatter Plot of Data
plt.subplot(2, 1, 1)
plt.scatter(range(len(crime_2015.Primcount)), crime_2015.Primcount, label="crime_2015")
plt.scatter(range(len(crime_2020.Primcount)), crime_2020.Primcount, label="crime_2020")
plt.legend()

# Histogram Plot of Data
plt.subplot(2, 1, 2)
plt.hist(crime_2015.Primcount, 10, density=True, alpha=0.7, label="crime_2015")
plt.hist(crime_2020.Primcount, 10, density=True, alpha=0.7, label="crime_2020")
plt.axvline(crime_2015.Primcount.mean(), color='k', linestyle='dashed', linewidth=1)
plt.axvline(crime_2020.Primcount.mean(), color='k', linestyle='dashed', linewidth=1)
plt.legend()
